# %%
! pip install roboflow
# Out:
# ...
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.3/38.8 MB ? eta -:--:--
#     --------------------------------------- 0.5/38.8 MB 1.0 MB/s eta 0:00:37
#     --------------------------------------- 0.8/38.8 MB 882.6 kB/s eta 0:00:44
#     --------------------------------------- 0.8/38.8 MB 882.6 kB/s eta 0:00:44
#    - -------------------------------------- 1.0/38.8 MB 825.2 kB/s eta 0:00:46
#    - -------------------------------------- 1.0/38.8 MB 825.2 kB/s eta 0:00:46
#    - -------------------------------------- 1.3/38.8 MB 838.9 kB/s eta 0:00:45
#    - -------------------------------------- 1.6/38.8 MB 822.3 kB/s eta 0:00:46
#    - -------------------------------------- 1.6/38.8 MB 822.3 kB/s eta 0:00:46
#    - -------------------------------------- 1.8/38.8 MB 818.3 kB/s eta 0:00:46
# ...

# %%
import os
import dotenv

# %%
dotenv.load_dotenv()
ROBOFLOW = os.getenv("ROBOFLOW")

# %%
import roboflow as rf
r = rf.Roboflow(api_key=ROBOFLOW)
project = r.workspace("treedataset-clsqo").project("tree-top-view")
version = project.version(6)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Tree-Top-View-6 in yolov8:: 100%|██████████| 2780/2780 [00:01<00:00, 1708.38it/s]
